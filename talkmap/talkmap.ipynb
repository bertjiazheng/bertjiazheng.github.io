# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Run this from the _talks/ directory, which contains .md files of all your talks. This scrapes the location YAML field from each .md file, geolocates it with geopy/Nominatim, and uses the getorg library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# !pip install getorg --upgrade
import getorg
from geopy import Nominatim
# Out:
# zsh:1: command not found: pip
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/4l/nmkf_zk50r51mjwqvvhbhgjw0000gn/T/ipykernel_24355/3410763293.py in <module>
#       1 get_ipython().system('pip install getorg --upgrade')
#       2 import glob
# ----> 3 import getorg
#       4 from geopy import Nominatim
#
# ~/anaconda3/lib/python3.7/site-packages/getorg/__init__.py in <module>
#       1 from __future__ import print_function
# ----> 2 from getorg import orgmap
#       3 from getorg import orgevents
#
# ~/anaconda3/lib/python3.7/site-packages/getorg/orgmap.py in <module>
#       1 from __future__ import print_function
# ----> 2 import github
#       3 from getorg.core import *
#       4 from geopy.geocoders import Nominatim
#       5 from retrying import retry
#
# ~/anaconda3/lib/python3.7/site-packages/github/__init__.py in <module>
#      54 import logging
#      55
# ---> 56 from github.MainClass import Github, GithubIntegration
#      57
#      58 from .GithubException import (
#
# ~/anaconda3/lib/python3.7/site-packages/github/MainClass.py in <module>
#      58
#      59 import github.ApplicationOAuth
# ---> 60 import github.Event
#      61 import github.Gist
#      62 import github.GithubObject
#
# ~/anaconda3/lib/python3.7/site-packages/github/Event.py in <module>
#      30
#      31 import github.GithubObject
# ---> 32 import github.NamedUser
#      33 import github.Organization
#      34 import github.Repository
#
# ~/anaconda3/lib/python3.7/site-packages/github/NamedUser.py in <module>
#      42 import github.GithubObject
#      43 import github.NamedUser
# ---> 44 import github.Organization
#      45 import github.PaginatedList
#      46 import github.Permissions
#
# ~/anaconda3/lib/python3.7/site-packages/github/Organization.py in <module>
#      48 import github.Plan
#      49 import github.Project
# ---> 50 import github.Repository
#      51 import github.Team
#      52
#
# ~/anaconda3/lib/python3.7/site-packages/github/Repository.py in <module>
#      90 from base64 import b64encode
#      91
# ---> 92 from deprecated import deprecated
#      93
#      94 import github.Branch
#
# ~/anaconda3/lib/python3.7/site-packages/deprecated/__init__.py in <module>
#      13 __credits__ = "(c) Laurent LAPORTE"
#      14
# ---> 15 from deprecated.classic import deprecated
#
# ~/anaconda3/lib/python3.7/site-packages/deprecated/classic.py in <module>
#      13 import warnings
#      14
# ---> 15 import wrapt
#      16
#      17 try:
#
# ModuleNotFoundError: No module named 'wrapt'

# %%
geocoder = Nominatim(user_agent="http")
location_dict = {}

# %%
locations = ["Tianjin, China", "Hangzhou, China", "Xi'an, China", "Hefei, China"]

# %%
for location in locations:
    location_dict[location] = geocoder.geocode(location)
    print(location, "\n", location_dict[location])
# Out:
# Xi'an, China
#  西安市, 陕西省, 中国
# Hangzhou, China
#  杭州市, 浙江省, 中国
# Hefei, China
#  合肥市, 安徽省, 中国

# %%
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name=".", hashed_usernames=False)
# Out:
# 'Written map to talkmap/'
